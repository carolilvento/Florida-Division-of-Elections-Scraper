# %%
import requests
from bs4 import BeautifulSoup

counties = ['ALA','BAK','BAY','BRA','BRE','BRO','CAL','CHA','CIT','CLA','CLL','CLM','DAD','DES','DIX','DUV','ESC','FLA','FRA','GAD','GIL','GLA','GUL','HAM','HAR','HEN','HER','HIG','HIL','HOL','IND','JAC','JEF','LAF','LAK','LEE','LEO','LEV','LIB','MAD','MAN','MON','MRN','MRT','NAS','OKA','OKE','ORA','OSC','PAL','PAS','PIN','POL','PUT','SAN','SAR','SEM','STJ','STL','SUM','SUW','TAY','UNI','VOL','WAK','WAL','WAS']

for y in counties:
    prefix = 'https://enr.electionsfl.org/' + y + '/'

    for x in range(2900, 3400):
        url = prefix + str(x) + '/Summary/'
        req = requests.get(url)
       #print(x, req)

        if req.status_code == 200:
            #print(x,req)
            soup = BeautifulSoup(req.content)
            print(y,x,soup.h1.text)
# Out:
# ALA 3117 2021 Gainesville Special Election
# ALA 3130 2022 Gainesville Special Runoff Election
# ALA 3197 2022 Primary Election
# ALA 3293 2022 General Election
# BAK 3217 Primary Election (08/23/2022)
# BAK 3315 General Election 2022
# BAY 2954 Lynn Haven Runoff Election
# BAY 3159 Municipal Super Tuesday Election
# BAY 3256 Primary Election
# BAY 3265 General Election
# BRA 3214 2022 Primary
# BRA 3308 2022 General
# BRE 3102 2021 Municipal and Special District Election
# BRE 3149 2022 Palm Bay Special Election
# BRE 3187 2022 Primary Election
# BRE 3299 2022 General Election
# BRO 3098 Special Primary Election
# BRO 3123 2022 Special Election & Special Primary Election
# BRO 3144 2022 Special Election & Municipal Election
# BRO 3163 2022 TEST ELECTION
# BRO 3200 2022 Primary Election
# BRO 3260 2022 Primary Election RECOUNT
# CAL 3230 2022 Primary Election
# CHA 3215 2022 Primary Election
# CHA 3331 2022 General Election
# CIT 3175 2022 Primary Election
# ...
